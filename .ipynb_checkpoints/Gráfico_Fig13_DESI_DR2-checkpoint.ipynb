# %%
#Este trabalho tem como objetivo reproduzir a FIG. 13 do artigo DESI DR2, página 26.
#Artigo principal: "DESI DR2 Results II: Measurements of Baryon Acoustic Oscillations and Cosmological Constraints" (https://arxiv.org/abs/2503.14738)
#Artigo citado ao longo do código: "Planck 2018 results. VI. Cosmological parameters" (http://arxiv.org/abs/1807.06209)

# %%
# CAMB LateDE
import numpy as np
import matplotlib.pyplot as plt
import camb, os, sys

#Check which CAMB is installed
print('Using CAMB %s installed at %s'%(camb.__version__,os.path.dirname(camb.__file__)))
# Out:
# Using CAMB 1.5.0 installed at C:\Users\Paula\anaconda3\Lib\site-packages\camb

# %%
#Fiducial: ΛCDM do Planck 2018

latede_cosmology = camb.set_params(# Background
                            H0 = 67.27, ombh2=0.02236, omch2=0.12091, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 1,
                            w0 =-1.0, 
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_fid = np.linspace(0.1, 3, 50)

# Distâncias e parâmetros derivados
DA_fid = results.angular_diameter_distance(z_fid)  # [Mpc]
H_fid  = results.hubble_parameter(z_fid)            # [km/s/Mpc]
r_s_fid      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DM_fid = (1 + z_fid) * DA_fid / r_s_fid
DH_fid = (3e5 / H_fid) / r_s_fid
DV_fid = ((z_fid * (DM_fid**2) * DH_fid)**(1/3))  # combinação isotrópica

# %%
#Gráfico para D_V

#DESI com barras de erro (a)
#ΛCDM: CMB (b)
#ΛCDM: DESY5 (c)
#ΛCDM: DESI (d)
#ΛCDM: DESI+CMB (e)

# %%
#DESI com barras de erro (a) (???????????????)

latede_cosmology = camb.set_params(# Background
                            H0 = 67.14, ombh2=0.02236, omch2=0.1204, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 1,
                            w0 =-1.0,
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_LCDM = np.linspace(0.1, 3, 50)

# Distâncias e parâmetros derivados
DAa_LCDM = results.angular_diameter_distance(z_LCDM)  # [Mpc]
Ha_LCDM  = results.hubble_parameter(z_LCDM)            # [km/s/Mpc]
r_s_a      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DMa_LCDM = (1 + z_LCDM) * DAa_LCDM / r_s_a
DHa_LCDM = (3e5 / Ha_LCDM) / r_s_a
DVa_LCDM = ((z_LCDM * (DMa_LCDM**2) * DHa_LCDM)**(1/3))  # combinação isotrópica

# %%
#ΛCDM: CMB (b)

latede_cosmology = camb.set_params(# Background
                            H0 = 67.14, ombh2=0.02236, omch2=0.1204, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 1,
                            w0 =-1.0,
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_LCDM = np.linspace(0.1, 3, 50)

# Distâncias e parâmetros derivados
DAb_LCDM = results.angular_diameter_distance(z_LCDM)  # [Mpc]
Hb_LCDM  = results.hubble_parameter(z_LCDM)            # [km/s/Mpc]
r_s_b      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DMb_LCDM = (1 + z_LCDM) * DAb_LCDM / r_s_b
DHb_LCDM = (3e5 / Hb_LCDM) / r_s_b
DVb_LCDM = ((z_LCDM * (DMb_LCDM**2) * DHb_LCDM)**(1/3))  # combinação isotrópica

# %%
#ΛCDM: DESY5 (c) (?????????????)

latede_cosmology = camb.set_params(# Background
                            H0 = 68.17, ombh2=0.02236, omch2=0.118308, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 1,
                            w0 =-1.0,
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_LCDM = np.linspace(0.1, 3, 50)

# Distâncias e parâmetros derivados
DAc_LCDM = results.angular_diameter_distance(z_LCDM)  # [Mpc]
Hc_LCDM  = results.hubble_parameter(z_LCDM)            # [km/s/Mpc]
r_s_c      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DMc_LCDM = (1 + z_LCDM) * DAc_LCDM / r_s_c
DHc_LCDM = (3e5 / Hc_LCDM) / r_s_c
DVc_LCDM = ((z_LCDM * (DMc_LCDM**2) * DHc_LCDM)**(1/3))  # combinação isotrópica

# %%
#ΛCDM: DESI (d) (Na falta do valor de H_0, utilizei H_0 de Planck 2018)

latede_cosmology = camb.set_params(# Background
                            H0 = 67.36, ombh2=0.02236, omch2=0.1125, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 1,
                            w0 =-1.0,
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_LCDM = np.linspace(0.1, 3, 50)

# Distâncias e parâmetros derivados
DAd_LCDM = results.angular_diameter_distance(z_LCDM)  # [Mpc]
Hd_LCDM  = results.hubble_parameter(z_LCDM)            # [km/s/Mpc]
r_s_d      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DMd_LCDM = (1 + z_LCDM) * DAd_LCDM / r_s_d
DHd_LCDM = (3e5 / Hd_LCDM) / r_s_d
DVd_LCDM = ((z_LCDM * (DMd_LCDM**2) * DHd_LCDM)**(1/3))  # combinação isotrópica

# %%
#ΛCDM: DESI+CMB (e)

latede_cosmology = camb.set_params(# Background
                            H0 = 68.17, ombh2=0.02236, omch2=0.1, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 1,
                            w0 =-1.0,
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_LCDM = np.linspace(0.1, 3, 50)

# Distâncias e parâmetros derivados
DAe_LCDM = results.angular_diameter_distance(z_LCDM)  # [Mpc]
He_LCDM  = results.hubble_parameter(z_LCDM)            # [km/s/Mpc]
r_s_e      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DMe_LCDM = (1 + z_LCDM) * DAe_LCDM / r_s_e
DHe_LCDM = (3e5 / He_LCDM) / r_s_e
DVe_LCDM = ((z_LCDM * (DMe_LCDM**2) * DHe_LCDM)**(1/3))  # combinação isotrópica

# %%
#Gráfico para D_V

plt.figure(figsize=(10,6))

# =======================
# 1. Normalização fiducial
# =======================

DV_fid_norm = (DV_fid / r_s_fid)

# =======================
# 2. Cada modelo cosmológico
# =======================

# DESI com barras de erro (a)
DVa_LCDM_norm = DVa_LCDM / r_s_a
plt.plot(z_LCDM, DVa_LCDM_norm / DV_fid_norm,
         label='DESI com barras de erro (a)')

# ΛCDM: CMB (b)
DVb_LCDM_norm = DVb_LCDM / r_s_b
plt.plot(z_LCDM, DVb_LCDM_norm / DV_fid_norm,
         label='ΛCDM: CMB (b)')

# ΛCDM: DESY5 (c)
DVc_LCDM_norm = DVc_LCDM / r_s_c
plt.plot(z_LCDM, DVc_LCDM_norm / DV_fid_norm,
         label='ΛCDM: DESY5 (c)')

# ΛCDM: DESI (d)
DVd_LCDM_norm = DVd_LCDM / r_s_d
plt.plot(z_LCDM, DVd_LCDM_norm / DV_fid_norm,
         label='ΛCDM: DESI (d)')

# ΛCDM: DESI+CMB (e)
DVe_LCDM_norm = DVe_LCDM / r_s_e
plt.plot(z_LCDM, DVe_LCDM_norm / DV_fid_norm,
         label='ΛCDM: DESI+CMB (e)')

# Se houver mais modelos, repetir o mesmo padrão acima


# =======================
# 3. Melhorias visuais
# =======================

plt.axhline(1.0, color='gray', linestyle=':', linewidth=1)  # linha y = 1

plt.xlabel(r'$z$', fontsize=14)
plt.ylabel(r'$(D_V/r_s) / (D_V/r_s)_{\rm fid}$', fontsize=16)

plt.title('Gráfico 1',
          fontsize=15)

plt.grid(alpha=0.25)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
#Gráfico para D_M

#DESI com barras de erro (f)
#wCDM: DESI+CMB+DESY5 (g)
#w0waCDM: DESI+DESY5 (h)
#w0waCDM: DESI+CMB+DESY5 (i)

# %%
#DESI com barras de erro (f) (???????????????)

latede_cosmology = camb.set_params(# Background
                            H0 = 67.14, ombh2=0.02236, omch2=0.1204, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 1,
                            w0 =-1.0,
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_w0wa = np.linspace(0.1, 2.5, 50)

# Distâncias e parâmetros derivados
DA_w0wa = results.angular_diameter_distance(z_w0wa)  # [Mpc]
H_w0wa  = results.hubble_parameter(z_w0wa)            # [km/s/Mpc]
r_s      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DMf_w0wa = (1 + z_w0wa) * DA_w0wa / r_s

# %%
#wCDM: DESI+CMB+DESY5 (g)

latede_cosmology = camb.set_params(# Background
                            H0 = 67.34, ombh2=0.022336, omch2=0.1180, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 2,
                            w0 =-0.961, w1 =0, 
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_w0wa = np.linspace(0.1, 2.5, 50)

# Distâncias e parâmetros derivados
DA_w0wa = results.angular_diameter_distance(z_w0wa)  # [Mpc]
H_w0wa  = results.hubble_parameter(z_w0wa)            # [km/s/Mpc]
r_s      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DMg_w0wa = (1 + z_w0wa) * DA_w0wa / r_s

# %%
#w0waCDM: DESI+DESY5 (h) (Na falta do valor de H_0, utilizei H_0 de Planck 2018)

latede_cosmology = camb.set_params(# Background
                            H0 = 67.36, ombh2=0.022336, omch2=0.1223, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 2,
                            w0 =-0.752, w1 =-0.86, 
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_w0wa = np.linspace(0.1, 2.5, 50)

# Distâncias e parâmetros derivados
DA_w0wa = results.angular_diameter_distance(z_w0wa)  # [Mpc]
H_w0wa  = results.hubble_parameter(z_w0wa)            # [km/s/Mpc]
r_s      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DMh_w0wa = (1 + z_w0wa) * DA_w0wa / r_s

# %%
#w0waCDM: DESI+CMB+DESY5 (i)

latede_cosmology = camb.set_params(# Background
                            H0 = 66.74, ombh2=0.022336, omch2=0.1196, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 2,
                            w0 =-0.758, w1 =-0.82, 
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_w0wa = np.linspace(0.1, 2.5, 50)

# Distâncias e parâmetros derivados
DA_w0wa = results.angular_diameter_distance(z_w0wa)  # [Mpc]
H_w0wa  = results.hubble_parameter(z_w0wa)            # [km/s/Mpc]
r_s      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DMi_w0wa = (1 + z_w0wa) * DA_w0wa / r_s

# %%
#Gráfico para D_H

#DESI com barras de erro (j)
#wCDM: DESI+CMB+DESY5 (k)
#w0waCDM: DESI+DESY5 (l)
#w0waCDM: DESI+CMB+DESY5 (m)

# %%
#DESI com barras de erro (j) (???????????????)

latede_cosmology = camb.set_params(# Background
                            H0 = 67.14, ombh2=0.02236, omch2=0.1204, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 1,
                            w0 =-1.0,
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_LCDM = np.linspace(0.1, 2.5, 50)

# Distâncias e parâmetros derivados
DA_LCDM = results.angular_diameter_distance(z_LCDM)  # [Mpc]
H_LCDM  = results.hubble_parameter(z_LCDM)            # [km/s/Mpc]
r_s      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DHj_LCDM = (3e5 / H_LCDM) / r_s

# %%
#wCDM: DESI+CMB+DESY5 (k)

latede_cosmology = camb.set_params(# Background
                            H0 = 67.34, ombh2=0.022336, omch2=0.1180, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 2,
                            w0 =-0.961, w1 =0, 
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_LCDM = np.linspace(0.1, 2.5, 50)

# Distâncias e parâmetros derivados
DA_LCDM = results.angular_diameter_distance(z_LCDM)  # [Mpc]
H_LCDM  = results.hubble_parameter(z_LCDM)            # [km/s/Mpc]
r_s      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DHk_LCDM = (3e5 / H_LCDM) / r_s

# %%
#w0waCDM: DESI+DESY5 (l) (Na falta do valor de H_0, utilizei H_0 de Planck 2018)

latede_cosmology = camb.set_params(# Background
                            H0 = 67.36, ombh2=0.022336, omch2=0.1223, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 2,
                            w0 =-0.752, w1 =-0.86, 
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_LCDM = np.linspace(0.1, 2.5, 50)

# Distâncias e parâmetros derivados
DA_LCDM = results.angular_diameter_distance(z_LCDM)  # [Mpc]
H_LCDM  = results.hubble_parameter(z_LCDM)            # [km/s/Mpc]
r_s      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DHl_LCDM = (3e5 / H_LCDM) / r_s

# %%
#w0waCDM: DESI+CMB+DESY5 (m)

latede_cosmology = camb.set_params(# Background
                            H0 = 66.74, ombh2=0.022336, omch2=0.1196, TCMB = 2.7255,
                            dark_energy_model = 'ppf',
                            DEmodel = 2,
                            w0 =-0.758, w1 =-0.82, 
                            # Neutrinos
                            omnuh2 = 0, num_nu_massless=3.044, num_nu_massive = 0,
                            nu_mass_degeneracies=[0], nu_mass_numbers = [0],
                            # Initial Power Spectrum
                            As = 2.100549e-09, ns = 0.9660499, 
                            YHe = 0.246, WantTransfer=True)

# %%
# Executar o cálculo
results = camb.get_results(latede_cosmology)

# Intervalo de redshift
z_LCDM = np.linspace(0.1, 2.5, 50)

# Distâncias e parâmetros derivados
DA_LCDM = results.angular_diameter_distance(z_LCDM)  # [Mpc]
H_LCDM  = results.hubble_parameter(z_LCDM)            # [km/s/Mpc]
r_s      = results.get_derived_params()['rdrag']        # [Mpc]

# Distâncias normalizadas
DHm_LCDM = (3e5 / H_LCDM) / r_s
